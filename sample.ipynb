# %% [markdown]
# # DATA CLEANING
#
# ## Handling Missing Values
#
# - **Columns with Missing Values:** [List of columns with missing values]
# - **Strategy:** [Describe the strategy chosen for handling missing values]
# - **Action Taken:** [Describe the action taken to handle missing values (e.g., removed rows, imputed values)]
# - **Rationale:** [Explain the rationale behind the chosen strategy]
#
# ---
#
# ## Removing Duplicates
#
# - **Action Taken:** [Describe the action taken to remove duplicates]
# - **Number of Duplicates Removed:** [Specify the number of duplicate entries removed]
# - **Rationale:** [Explain why duplicate entries were removed]
#
# ---
#
# ## Standardizing Formats
#
# - **Columns Checked:** [List of columns checked for inconsistent formatting]
# - **Actions Taken:** [Describe the actions taken to standardize formats]
# - **Rationale:** [Explain why standardization was necessary]
#
# ---
#
# ## Validating Data Integrity
#
# - **Actions Taken:** [Describe the actions taken to validate data integrity]
# - **Findings:** [Report any outliers, inconsistencies, or anomalies identified]
# - **Corrections Made:** [Describe any corrections or adjustments made]
# - **Rationale:** [Explain why corrections or adjustments were necessary]
#
# ---
#
# ## Additional Issues/Other Changes Encountered
#
# - **Description:** [Describe the additional issue encountered]
# - **Actions Taken:** [Describe any corrections or adjustments made]
# - **Rationale:** [Explain why corrections or adjustments were necessary]

# %% [markdown]
# # Data Cleaning
#
# ## Handling Missing Values
#
# - **Columns with Missing Values:**
#   - [List of columns with missing values]
#
# - **Strategy:**
#   - [Describe the strategy chosen for handling missing values]
#
# - **Action Taken:**
#   - [Describe the action taken to handle missing values (e.g., removed rows, imputed values)]
#
# - **Rationale:**
#   - [Explain the rationale behind the chosen strategy]
#
# ---
#
# ## Removing Duplicates
#
# - **Action Taken:**
#   - [Describe the action taken to remove duplicates]
#
# - **Number of Duplicates Removed:**
#   - [Specify the number of duplicate entries removed]
#
# - **Rationale:**
#   - [Explain why duplicate entries were removed]
#
# ---
#
# ## Standardizing Formats
#
# - **Columns Checked:**
#   - [List of columns checked for inconsistent formatting]
#
# - **Actions Taken:**
#   - [Describe the actions taken to standardize formats]
#
# - **Rationale:**
#   - [Explain why standardization was necessary]
#
# ---
#
# ## Validating Data Integrity
#
# - **Actions Taken:**
#   - [Describe the actions taken to validate data integrity]
#
# - **Findings:**
#   - [Report any outliers, inconsistencies, or anomalies identified]
#
# - **Corrections Made:**
#   - [Describe any corrections or adjustments made]
#
# - **Rationale:**
#   - [Explain why corrections or adjustments were necessary]
#
# ---
#
# ## Additional Issues/Other Changes Encountered
#
# - **Description:**
#   - [Describe the additional issue encountered]
#
# - **Actions Taken:**
#   - [Describe any corrections or adjustments made]
#
# - **Rationale:**
#   - [Explain why corrections or adjustments were necessary]
